# %%
import time
import os
import raco.viz

import findspark
findspark.init()
findspark.add_packages('com.databricks:spark-csv_2.10:1.4.0')

from raco.backends.spark.connection import SparkConnection
from raco.backends.spark.catalog import SparkCatalog
from raco.backends.spark.algebra import SparkAlgebra

from raco.backends.logical import OptLogicalAlgebra
from raco.catalog import FromFileCatalog
import raco.myrial.interpreter as interpreter
import raco.myrial.parser as myrialparser

from raco.backends.myria import MyriaLeftDeepTreeAlgebra
from raco.backends.myria.connection import MyriaConnection
from raco.backends.myria.catalog import MyriaCatalog

import accumulo
from raco.backends.accumulo.connection import AccumuloConnection
from raco.backends.accumulo.catalog import AccumuloCatalog

from raco.backends.federated.connection import FederatedConnection
from raco.backends.federated.catalog import FederatedCatalog
from raco.backends.federated.algebra import FederatedAlgebra

# %%
masterHostname = os.environ.get('sparkurl', 'localhost')
def get_accumulo_connection():
    host='localhost'
    port=42424
    user='root'
    pw='secret'
    return AccumuloConnection(host, port, user, pw) 

def get_spark_connection():
    masterHostname = os.environ.get('sparkurl', 'localhost')
    if masterHostname == 'localhost':
        return SparkConnection(masterHostname)
    return SparkConnection("spark://{masterHostname}:7077".format(masterHostname=masterHostname))

# %%
##Initialize Backend Accumulo
accumuloconn = get_accumulo_connection()
accumulocatalog = AccumuloCatalog(accumuloconn)

##Initialize Backend Spark
sparkconn = get_spark_connection()
sparkcatalog = SparkCatalog.load_from_file(os.path.join(os.path.abspath('./examples/'), 'catalog.py'))

##Initialize Federated Backend
fed_conn = FederatedConnection([accumuloconn, sparkconn])
fed_catalog = FederatedCatalog([accumulocatalog, sparkcatalog])

# %%
##The Jaccard Computation expressed as MyriaL query
program_fquery="""
-- Scan netflow data (this resides in Accumulo)
NF = scan(netflow);
-- Filter the dataset (runs on Accumulo)
NFSUB = select SrcAddr as src_ip, DstAddr as dst_ip, 1.0 as value from NF where TotBytes > 100;
-- Scan DNS dataset (this is accessible to Spark)
DNS = scan('/home/dhutchis/gits/raco/examples/fed_accumulo_spark_c/dnssample_parsed.txt');
-- Perform a Join (Automatically move the datasets as necessary)
graph = select d1.dns as row, d2.dns as col, n.value
		from NFSUB n, DNS d1, DNS d2
	    where n.src_ip = d1.ip and n.dst_ip = d2.ip;

--Begin Jaccard
-- Calculate common neighbours
gammas = select a.row as u, b.row as v, count(b.value) as gamma
		 from graph a, graph b
         where a.col == b.col;

-- Calculate the out_degree of each vertex
out_d = select row, count(value) as od from graph;

-- Calculate the Jaccard Coefficients for all pairs (u,v);
J = select a.u as src_name, a.v as dst_name, a.gamma/(b.od + c.od - a.gamma) as jaccard_coeff
	from gammas a, out_d b, out_d c
    where a.u = b.row and a.v = c.row;

-- Store the result
store(J, nameJaccard);
"""

# %%
##Parse the query
parser = myrialparser.Parser()
processor = interpreter.StatementProcessor(fed_catalog, True)
statement_list = parser.parse(program_fquery)
processor.evaluate(statement_list)
# Out:
# Relation not present try other catalogs
# Relation not present try other catalogs

# %%
##Lets Visualize the query
logical_plan = processor.get_logical_plan()
dot_logical = raco.viz.operator_to_dot_object(logical_plan)
dot_logical.view()

# %%
##Let's optimize the query and let the federation figure out the right backends
algebras = [OptLogicalAlgebra(), MyriaLeftDeepTreeAlgebra(), SparkAlgebra()]
falg = FederatedAlgebra(algebras, fed_catalog)
federated_plan = processor.get_physical_plan(target_alg=falg)
# Out:
# Relation not present try other catalogs
# Relation not present try other catalogs
# Relation not present try other catalogs
# Relation not present try other catalogs
# Relation not present try other catalogs
# Relation not present try other catalogs
# Relation not present try other catalogs
# Relation not present try other catalogs

# %%
##Visualizing the physical plan
raco.viz.operator_to_dot_object(federated_plan).view()

# %%
##Submit the plan for federated execution
fed_conn.execute_query(federated_plan)
# Out:
# +--------------------+--------------------+------------------+
# |            src_name|            dst_name|     jaccard_coeff|
# +--------------------+--------------------+------------------+
# |       hn.kd.ny.adsl|       hn.kd.ny.adsl|               1.0|
# |178.111.dsl.mel.i...|       hn.kd.ny.adsl|              0.25|
# |97-127-34-181.mpl...|       hn.kd.ny.adsl|               0.5|
# |smtp179.emergency...|       hn.kd.ny.adsl|0.3333333333333333|
# |189.114.211.178.d...|189.114.211.178.d...|               1.0|
# |       hn.kd.ny.adsl|178.111.dsl.mel.i...|              0.25|
# |178.111.dsl.mel.i...|178.111.dsl.mel.i...|               1.0|
# |smtp179.emergency...|178.111.dsl.mel.i...|              0.25|
# |       hn.kd.ny.adsl|97-127-34-181.mpl...|               0.5|
# |97-127-34-181.mpl...|97-127-34-181.mpl...|               1.0|
# |smtp179.emergency...|97-127-34-181.mpl...|               0.5|
# |ip65-47-243-178.z...|ip65-47-243-178.z...|               1.0|
# |       hn.kd.ny.adsl|smtp179.emergency...|0.3333333333333333|
# |178.111.dsl.mel.i...|smtp179.emergency...|              0.25|
# |97-127-34-181.mpl...|smtp179.emergency...|               0.5|
# |smtp179.emergency...|smtp179.emergency...|               1.0|
# +--------------------+--------------------+------------------+
# (16, 'nameJaccard')

# %%
from raco.backends.cpp.cpp import CCAlgebra

##Initialize C Backend Catalog
c_catalog = FromFileCatalog.load_from_file(os.path.join(
                                               os.path.dirname('/home/dhutchis/gits/raco/examples/'), 
                                               'catalog.py'))

##Initialize Federated Backend -- With the C catalog
fed_conn = FederatedConnection([accumuloconn])
fed_catalog = FederatedCatalog([accumulocatalog, c_catalog])

##Parse the query -- SAME AS BEFORE
parser = myrialparser.Parser()
processor = interpreter.StatementProcessor(fed_catalog, True)
statement_list = parser.parse(program_fquery)
processor.evaluate(statement_list)

##Change to C Algebra 
algebras = [OptLogicalAlgebra(), MyriaLeftDeepTreeAlgebra(), CCAlgebra()]
falg = FederatedAlgebra(algebras, fed_catalog, crossproducts=False)
federated_plan = processor.get_physical_plan(target_alg=falg)
##Visualizing the physical plan
raco.viz.operator_to_dot_object(federated_plan).view()
# Out:
# Relation not present try other catalogs
# Relation not present try other catalogs
# Relation not present try other catalogs
# Relation not present try other catalogs
# Relation not present try other catalogs
# Relation not present try other catalogs
# Relation not present try other catalogs
# Relation not present try other catalogs
# Relation not present try other catalogs
# Relation not present try other catalogs
# 'Digraph.gv.pdf'

# %%
fed_conn.execute_query(federated_plan)
# Out:
# // Precount_select: Use buckets to track the number of matches
# // Use buckets to copy into the result array
# #include <cstdio>
# #include <cstdlib>     // for exit()
# #include <fcntl.h>      // for open()
# #include <unistd.h>     // for close()
# #include <sys/stat.h>   // for fstat()
# #include <ctype.h>      // for isdigit()
# #include <cstring>
# #include <errno.h>
# #include <algorithm>
# #include <sys/types.h>
# #include <sys/stat.h>
# #include <sys/file.h>
#
# #ifdef __MTA__
# #include <machine/runtime.h>
# #include <luc/luc_common.h>
# #include <snapshot/client.h>
# #include <sys/mta_task.h>
#
#
# typedef int int64;
# typedef unsigned uint64;
# #else
# #include <sys/time.h>
#
# #include <iomanip>
# #include <cstdint>
# #include <iostream>
# #include <fstream>
# typedef int64_t int64;
# typedef uint64_t uint64;
#
# #include <unordered_map>
# #include <vector>
# #include <limits>
# #endif
#
# #include "io_util.h"
# #include "hash.h"
# #include "radish_utils.h"
# #include "strings.h"
# #include "timing.h"
#
# // ------------------------------------------------------------------
#
#
#           // can be just the necessary schema
#   class MaterializedTupleRef_V8596059147_0_1_2 {
#     // Invariant: data stored in _fields is always in the representation
#     // specified by _scheme.
#
#     public:
#
#         std::array<char, MAX_STR_LEN> f0;
#
#         std::array<char, MAX_STR_LEN> f1;
#
#         double f2;
#
#
#     static constexpr int numFields() {
#       return 3;
#     }
#
#     // size of all fields in struct removing only end padding
#     static size_t fieldsSize() {
#         const MaterializedTupleRef_V8596059147_0_1_2 _t;
#         return
#
#
#             ((char*)&_t.f2) + sizeof(_t.f2) - ((char*)&_t);
#
#     }
#
#     // debugging function to get storage sizes
#     static void print_representation() {
#         const MaterializedTupleRef_V8596059147_0_1_2 _t;
#
#
#
#         std::cout << (((char*)&_t.f1) - ((char*)&_t.f0)) << ",";
#
#         std::cout << (((char*)&_t.f2) - ((char*)&_t.f1)) << ",";
#
#         std::cout << (_t.fieldsSize() - (((char*)&_t.f1) - ((char*)&_t)));
#         std::cout << std::endl;
#
#
#
#     }
#
#     MaterializedTupleRef_V8596059147_0_1_2 () {
#       // no-op
#     }
#
#     //template <typename OT>
#     //MaterializedTupleRef_V8596059147_0_1_2 (const OT& other) {
#     //  std::memcpy(this, &other, sizeof(MaterializedTupleRef_V8596059147_0_1_2));
#     //}
#
#     MaterializedTupleRef_V8596059147_0_1_2 (
#                                const std::array<char, MAX_STR_LEN>& a0
#                                ,
#
#                                const std::array<char, MAX_STR_LEN>& a1
#                                ,
#
#                                const double& a2
#
#
#                        ) {
#
#             f0 = a0;
#
#             f1 = a1;
#
#             f2 = a2;
#
#     }
#
#
#
#
#
#
#     MaterializedTupleRef_V8596059147_0_1_2(const std::tuple<
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         double
#
#
#             >& o) {
#
#             f0 = std::get<0>(o);
#
#             f1 = std::get<1>(o);
#
#             f2 = std::get<2>(o);
#
#      }
#
#      std::tuple<
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         double
#
#
#      > to_tuple() {
#
#         std::tuple<
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         double
#
#
#         > r;
#
#             std::get<0>(r) = f0;
#
#             std::get<1>(r) = f1;
#
#             std::get<2>(r) = f2;
#
#         return r;
#      }
#
#     // shamelessly terrible disambiguation: one solution is named factory methods
#     //MaterializedTupleRef_V8596059147_0_1_2 (std::vector<int64_t> vals, bool ignore1, bool ignore2) {
#     //
#     //        f0 = vals[0];
#     //
#     //        f1 = vals[1];
#     //
#     //        f2 = vals[2];
#     //
#     //}
#
#     // use the tuple schema to interpret the input stream
#     static MaterializedTupleRef_V8596059147_0_1_2 fromIStream(std::istream& ss, char delim=' ') {
#         MaterializedTupleRef_V8596059147_0_1_2 _ret;
#
#
#
#                {
#                std::string _temp;
#                std::getline(ss, _temp, delim);
#                // beware; truncate= true, so unckecked truncation for stringlen >= MAX_STR_LEN!
#                _ret.f0 = to_array<MAX_STR_LEN, std::string, true>(_temp);
#                }
#
#
#
#                {
#                std::string _temp;
#                std::getline(ss, _temp, delim);
#                // beware; truncate= true, so unckecked truncation for stringlen >= MAX_STR_LEN!
#                _ret.f1 = to_array<MAX_STR_LEN, std::string, true>(_temp);
#                }
#
#
#
#                {
#                // use operator>> to parse into proper numeric type
#                ss >> _ret.f2;
#                //throw away the next delimiter
#                std::string _temp;
#                std::getline(ss, _temp, delim);
#                }
#
#
#
#         return _ret;
#     }
#
#     void toOStream(std::ostream& os) const {
#         os.write((char*)this, this->fieldsSize());
#     }
#
#     void toOStreamAscii(std::ostream& os) const {
#         os
#
#
#         << f0 << " "
#
#         << f1 << " "
#
#         << f2 <<
#
#         std::endl;
#     }
#
#     //template <typename Tuple, typename T>
#     //MaterializedTupleRef_V8596059147_0_1_2 (const Tuple& v0, const T& from) {
#     //    constexpr size_t v0_size = std::tuple_size<Tuple>::value;
#     //    constexpr int from_size = T::numFields();
#     //    static_assert(MaterializedTupleRef_V8596059147_0_1_2::numFields() == (v0_size + from_size), "constructor only works on same number of total fields");
#     //    TupleUtils::assign<0, decltype(_scheme)>(_fields, v0);
#     //    std::memcpy(((char*)&_fields)+v0_size*sizeof(int64_t), &(from._fields), from_size*sizeof(int64_t));
#     //}
#
#     //template <typename Tuple>
#     //MaterializedTupleRef_V8596059147_0_1_2 (const Tuple& v0) {
#     //    static_assert(MaterializedTupleRef_V8596059147_0_1_2::numFields() == (std::tuple_size<Tuple>::value), "constructor only works on same number of total fields");
#     //    TupleUtils::assign<0, decltype(_scheme)>(_fields, v0);
#     //}
#
#     std::ostream& dump(std::ostream& o) const {
#       o << "Materialized(";
#
#
#         o << f0 << ",";
#
#         o << f1 << ",";
#
#         o << f2 << ",";
#
#
#       o << ")";
#       return o;
#     }
#
#     public:
#     static MaterializedTupleRef_V8596059147_0_1_2 fromRelationInfo(relationInfo * rel, int row) {
#         // DOESN'T WORK WITH SCHEMAS WITH STRINGS
#       MaterializedTupleRef_V8596059147_0_1_2 _t;
#
#          _t.f0 = *(std::array<char, MAX_STR_LEN>*)(&(rel->relation[row*rel->fields+0]));
#
#          _t.f1 = *(std::array<char, MAX_STR_LEN>*)(&(rel->relation[row*rel->fields+1]));
#
#          _t.f2 = *(double*)(&(rel->relation[row*rel->fields+2]));
#
#       return _t;
#     }
#   } ;
#
#   std::ostream& operator<< (std::ostream& o, const MaterializedTupleRef_V8596059147_0_1_2& t) {
#     return t.dump(o);
#   }
#
#           // can be just the necessary schema
#   class MaterializedTupleRef_V2356188225_0_1_2_3_4 {
#     // Invariant: data stored in _fields is always in the representation
#     // specified by _scheme.
#
#     public:
#
#         std::array<char, MAX_STR_LEN> f0;
#
#         std::array<char, MAX_STR_LEN> f1;
#
#         int64_t f2;
#
#         int64_t f3;
#
#         int64_t f4;
#
#
#     static constexpr int numFields() {
#       return 5;
#     }
#
#     // size of all fields in struct removing only end padding
#     static size_t fieldsSize() {
#         const MaterializedTupleRef_V2356188225_0_1_2_3_4 _t;
#         return
#
#
#             ((char*)&_t.f4) + sizeof(_t.f4) - ((char*)&_t);
#
#     }
#
#     // debugging function to get storage sizes
#     static void print_representation() {
#         const MaterializedTupleRef_V2356188225_0_1_2_3_4 _t;
#
#
#
#         std::cout << (((char*)&_t.f1) - ((char*)&_t.f0)) << ",";
#
#         std::cout << (((char*)&_t.f2) - ((char*)&_t.f1)) << ",";
#
#         std::cout << (((char*)&_t.f3) - ((char*)&_t.f2)) << ",";
#
#         std::cout << (((char*)&_t.f4) - ((char*)&_t.f3)) << ",";
#
#         std::cout << (_t.fieldsSize() - (((char*)&_t.f3) - ((char*)&_t)));
#         std::cout << std::endl;
#
#
#
#     }
#
#     MaterializedTupleRef_V2356188225_0_1_2_3_4 () {
#       // no-op
#     }
#
#     //template <typename OT>
#     //MaterializedTupleRef_V2356188225_0_1_2_3_4 (const OT& other) {
#     //  std::memcpy(this, &other, sizeof(MaterializedTupleRef_V2356188225_0_1_2_3_4));
#     //}
#
#     MaterializedTupleRef_V2356188225_0_1_2_3_4 (
#                                const std::array<char, MAX_STR_LEN>& a0
#                                ,
#
#                                const std::array<char, MAX_STR_LEN>& a1
#                                ,
#
#                                const int64_t& a2
#                                ,
#
#                                const int64_t& a3
#                                ,
#
#                                const int64_t& a4
#
#
#                        ) {
#
#             f0 = a0;
#
#             f1 = a1;
#
#             f2 = a2;
#
#             f3 = a3;
#
#             f4 = a4;
#
#     }
#
#
#
#
#
#
#     MaterializedTupleRef_V2356188225_0_1_2_3_4(const std::tuple<
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         int64_t
#         ,
#
#         int64_t
#         ,
#
#         int64_t
#
#
#             >& o) {
#
#             f0 = std::get<0>(o);
#
#             f1 = std::get<1>(o);
#
#             f2 = std::get<2>(o);
#
#             f3 = std::get<3>(o);
#
#             f4 = std::get<4>(o);
#
#      }
#
#      std::tuple<
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         int64_t
#         ,
#
#         int64_t
#         ,
#
#         int64_t
#
#
#      > to_tuple() {
#
#         std::tuple<
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         int64_t
#         ,
#
#         int64_t
#         ,
#
#         int64_t
#
#
#         > r;
#
#             std::get<0>(r) = f0;
#
#             std::get<1>(r) = f1;
#
#             std::get<2>(r) = f2;
#
#             std::get<3>(r) = f3;
#
#             std::get<4>(r) = f4;
#
#         return r;
#      }
#
#     // shamelessly terrible disambiguation: one solution is named factory methods
#     //MaterializedTupleRef_V2356188225_0_1_2_3_4 (std::vector<int64_t> vals, bool ignore1, bool ignore2) {
#     //
#     //        f0 = vals[0];
#     //
#     //        f1 = vals[1];
#     //
#     //        f2 = vals[2];
#     //
#     //        f3 = vals[3];
#     //
#     //        f4 = vals[4];
#     //
#     //}
#
#     // use the tuple schema to interpret the input stream
#     static MaterializedTupleRef_V2356188225_0_1_2_3_4 fromIStream(std::istream& ss, char delim=' ') {
#         MaterializedTupleRef_V2356188225_0_1_2_3_4 _ret;
#
#
#
#                {
#                std::string _temp;
#                std::getline(ss, _temp, delim);
#                // beware; truncate= true, so unckecked truncation for stringlen >= MAX_STR_LEN!
#                _ret.f0 = to_array<MAX_STR_LEN, std::string, true>(_temp);
#                }
#
#
#
#                {
#                std::string _temp;
#                std::getline(ss, _temp, delim);
#                // beware; truncate= true, so unckecked truncation for stringlen >= MAX_STR_LEN!
#                _ret.f1 = to_array<MAX_STR_LEN, std::string, true>(_temp);
#                }
#
#
#
#                {
#                // use operator>> to parse into proper numeric type
#                ss >> _ret.f2;
#                //throw away the next delimiter
#                std::string _temp;
#                std::getline(ss, _temp, delim);
#                }
#
#
#
#                {
#                // use operator>> to parse into proper numeric type
#                ss >> _ret.f3;
#                //throw away the next delimiter
#                std::string _temp;
#                std::getline(ss, _temp, delim);
#                }
#
#
#
#                {
#                // use operator>> to parse into proper numeric type
#                ss >> _ret.f4;
#                //throw away the next delimiter
#                std::string _temp;
#                std::getline(ss, _temp, delim);
#                }
#
#
#
#         return _ret;
#     }
#
#     void toOStream(std::ostream& os) const {
#         os.write((char*)this, this->fieldsSize());
#     }
#
#     void toOStreamAscii(std::ostream& os) const {
#         os
#
#
#         << f0 << " "
#
#         << f1 << " "
#
#         << f2 << " "
#
#         << f3 << " "
#
#         << f4 <<
#
#         std::endl;
#     }
#
#     //template <typename Tuple, typename T>
#     //MaterializedTupleRef_V2356188225_0_1_2_3_4 (const Tuple& v0, const T& from) {
#     //    constexpr size_t v0_size = std::tuple_size<Tuple>::value;
#     //    constexpr int from_size = T::numFields();
#     //    static_assert(MaterializedTupleRef_V2356188225_0_1_2_3_4::numFields() == (v0_size + from_size), "constructor only works on same number of total fields");
#     //    TupleUtils::assign<0, decltype(_scheme)>(_fields, v0);
#     //    std::memcpy(((char*)&_fields)+v0_size*sizeof(int64_t), &(from._fields), from_size*sizeof(int64_t));
#     //}
#
#     //template <typename Tuple>
#     //MaterializedTupleRef_V2356188225_0_1_2_3_4 (const Tuple& v0) {
#     //    static_assert(MaterializedTupleRef_V2356188225_0_1_2_3_4::numFields() == (std::tuple_size<Tuple>::value), "constructor only works on same number of total fields");
#     //    TupleUtils::assign<0, decltype(_scheme)>(_fields, v0);
#     //}
#
#     std::ostream& dump(std::ostream& o) const {
#       o << "Materialized(";
#
#
#         o << f0 << ",";
#
#         o << f1 << ",";
#
#         o << f2 << ",";
#
#         o << f3 << ",";
#
#         o << f4 << ",";
#
#
#       o << ")";
#       return o;
#     }
#
#     public:
#     static MaterializedTupleRef_V2356188225_0_1_2_3_4 fromRelationInfo(relationInfo * rel, int row) {
#         // DOESN'T WORK WITH SCHEMAS WITH STRINGS
#       MaterializedTupleRef_V2356188225_0_1_2_3_4 _t;
#
#          _t.f0 = *(std::array<char, MAX_STR_LEN>*)(&(rel->relation[row*rel->fields+0]));
#
#          _t.f1 = *(std::array<char, MAX_STR_LEN>*)(&(rel->relation[row*rel->fields+1]));
#
#          _t.f2 = *(int64_t*)(&(rel->relation[row*rel->fields+2]));
#
#          _t.f3 = *(int64_t*)(&(rel->relation[row*rel->fields+3]));
#
#          _t.f4 = *(int64_t*)(&(rel->relation[row*rel->fields+4]));
#
#       return _t;
#     }
#   } ;
#
#   std::ostream& operator<< (std::ostream& o, const MaterializedTupleRef_V2356188225_0_1_2_3_4& t) {
#     return t.dump(o);
#   }
#
#           // can be just the necessary schema
#   class MaterializedTupleRef_V1141216908_0_1 {
#     // Invariant: data stored in _fields is always in the representation
#     // specified by _scheme.
#
#     public:
#
#         std::array<char, MAX_STR_LEN> f0;
#
#         int64_t f1;
#
#
#     static constexpr int numFields() {
#       return 2;
#     }
#
#     // size of all fields in struct removing only end padding
#     static size_t fieldsSize() {
#         const MaterializedTupleRef_V1141216908_0_1 _t;
#         return
#
#
#             ((char*)&_t.f1) + sizeof(_t.f1) - ((char*)&_t);
#
#     }
#
#     // debugging function to get storage sizes
#     static void print_representation() {
#         const MaterializedTupleRef_V1141216908_0_1 _t;
#
#
#
#         std::cout << (((char*)&_t.f1) - ((char*)&_t.f0)) << ",";
#
#         std::cout << (_t.fieldsSize() - (((char*)&_t.f0) - ((char*)&_t)));
#         std::cout << std::endl;
#
#
#
#     }
#
#     MaterializedTupleRef_V1141216908_0_1 () {
#       // no-op
#     }
#
#     //template <typename OT>
#     //MaterializedTupleRef_V1141216908_0_1 (const OT& other) {
#     //  std::memcpy(this, &other, sizeof(MaterializedTupleRef_V1141216908_0_1));
#     //}
#
#     MaterializedTupleRef_V1141216908_0_1 (
#                                const std::array<char, MAX_STR_LEN>& a0
#                                ,
#
#                                const int64_t& a1
#
#
#                        ) {
#
#             f0 = a0;
#
#             f1 = a1;
#
#     }
#
#
#
#
#
#
#     MaterializedTupleRef_V1141216908_0_1(const std::tuple<
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         int64_t
#
#
#             >& o) {
#
#             f0 = std::get<0>(o);
#
#             f1 = std::get<1>(o);
#
#      }
#
#      std::tuple<
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         int64_t
#
#
#      > to_tuple() {
#
#         std::tuple<
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         int64_t
#
#
#         > r;
#
#             std::get<0>(r) = f0;
#
#             std::get<1>(r) = f1;
#
#         return r;
#      }
#
#     // shamelessly terrible disambiguation: one solution is named factory methods
#     //MaterializedTupleRef_V1141216908_0_1 (std::vector<int64_t> vals, bool ignore1, bool ignore2) {
#     //
#     //        f0 = vals[0];
#     //
#     //        f1 = vals[1];
#     //
#     //}
#
#     // use the tuple schema to interpret the input stream
#     static MaterializedTupleRef_V1141216908_0_1 fromIStream(std::istream& ss, char delim=' ') {
#         MaterializedTupleRef_V1141216908_0_1 _ret;
#
#
#
#                {
#                std::string _temp;
#                std::getline(ss, _temp, delim);
#                // beware; truncate= true, so unckecked truncation for stringlen >= MAX_STR_LEN!
#                _ret.f0 = to_array<MAX_STR_LEN, std::string, true>(_temp);
#                }
#
#
#
#                {
#                // use operator>> to parse into proper numeric type
#                ss >> _ret.f1;
#                //throw away the next delimiter
#                std::string _temp;
#                std::getline(ss, _temp, delim);
#                }
#
#
#
#         return _ret;
#     }
#
#     void toOStream(std::ostream& os) const {
#         os.write((char*)this, this->fieldsSize());
#     }
#
#     void toOStreamAscii(std::ostream& os) const {
#         os
#
#
#         << f0 << " "
#
#         << f1 <<
#
#         std::endl;
#     }
#
#     //template <typename Tuple, typename T>
#     //MaterializedTupleRef_V1141216908_0_1 (const Tuple& v0, const T& from) {
#     //    constexpr size_t v0_size = std::tuple_size<Tuple>::value;
#     //    constexpr int from_size = T::numFields();
#     //    static_assert(MaterializedTupleRef_V1141216908_0_1::numFields() == (v0_size + from_size), "constructor only works on same number of total fields");
#     //    TupleUtils::assign<0, decltype(_scheme)>(_fields, v0);
#     //    std::memcpy(((char*)&_fields)+v0_size*sizeof(int64_t), &(from._fields), from_size*sizeof(int64_t));
#     //}
#
#     //template <typename Tuple>
#     //MaterializedTupleRef_V1141216908_0_1 (const Tuple& v0) {
#     //    static_assert(MaterializedTupleRef_V1141216908_0_1::numFields() == (std::tuple_size<Tuple>::value), "constructor only works on same number of total fields");
#     //    TupleUtils::assign<0, decltype(_scheme)>(_fields, v0);
#     //}
#
#     std::ostream& dump(std::ostream& o) const {
#       o << "Materialized(";
#
#
#         o << f0 << ",";
#
#         o << f1 << ",";
#
#
#       o << ")";
#       return o;
#     }
#
#     public:
#     static MaterializedTupleRef_V1141216908_0_1 fromRelationInfo(relationInfo * rel, int row) {
#         // DOESN'T WORK WITH SCHEMAS WITH STRINGS
#       MaterializedTupleRef_V1141216908_0_1 _t;
#
#          _t.f0 = *(std::array<char, MAX_STR_LEN>*)(&(rel->relation[row*rel->fields+0]));
#
#          _t.f1 = *(int64_t*)(&(rel->relation[row*rel->fields+1]));
#
#       return _t;
#     }
#   } ;
#
#   std::ostream& operator<< (std::ostream& o, const MaterializedTupleRef_V1141216908_0_1& t) {
#     return t.dump(o);
#   }
#
# std::unordered_map<std::array<char, MAX_STR_LEN>,int64_t> group_hash_000;
#           // can be just the necessary schema
#   class MaterializedTupleRef_V3993442750_0_1 {
#     // Invariant: data stored in _fields is always in the representation
#     // specified by _scheme.
#
#     public:
#
#         std::array<char, MAX_STR_LEN> f0;
#
#         double f1;
#
#
#     static constexpr int numFields() {
#       return 2;
#     }
#
#     // size of all fields in struct removing only end padding
#     static size_t fieldsSize() {
#         const MaterializedTupleRef_V3993442750_0_1 _t;
#         return
#
#
#             ((char*)&_t.f1) + sizeof(_t.f1) - ((char*)&_t);
#
#     }
#
#     // debugging function to get storage sizes
#     static void print_representation() {
#         const MaterializedTupleRef_V3993442750_0_1 _t;
#
#
#
#         std::cout << (((char*)&_t.f1) - ((char*)&_t.f0)) << ",";
#
#         std::cout << (_t.fieldsSize() - (((char*)&_t.f0) - ((char*)&_t)));
#         std::cout << std::endl;
#
#
#
#     }
#
#     MaterializedTupleRef_V3993442750_0_1 () {
#       // no-op
#     }
#
#     //template <typename OT>
#     //MaterializedTupleRef_V3993442750_0_1 (const OT& other) {
#     //  std::memcpy(this, &other, sizeof(MaterializedTupleRef_V3993442750_0_1));
#     //}
#
#     MaterializedTupleRef_V3993442750_0_1 (
#                                const std::array<char, MAX_STR_LEN>& a0
#                                ,
#
#                                const double& a1
#
#
#                        ) {
#
#             f0 = a0;
#
#             f1 = a1;
#
#     }
#
#
#
#
#
#
#     MaterializedTupleRef_V3993442750_0_1(const std::tuple<
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         double
#
#
#             >& o) {
#
#             f0 = std::get<0>(o);
#
#             f1 = std::get<1>(o);
#
#      }
#
#      std::tuple<
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         double
#
#
#      > to_tuple() {
#
#         std::tuple<
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         double
#
#
#         > r;
#
#             std::get<0>(r) = f0;
#
#             std::get<1>(r) = f1;
#
#         return r;
#      }
#
#     // shamelessly terrible disambiguation: one solution is named factory methods
#     //MaterializedTupleRef_V3993442750_0_1 (std::vector<int64_t> vals, bool ignore1, bool ignore2) {
#     //
#     //        f0 = vals[0];
#     //
#     //        f1 = vals[1];
#     //
#     //}
#
#     // use the tuple schema to interpret the input stream
#     static MaterializedTupleRef_V3993442750_0_1 fromIStream(std::istream& ss, char delim=' ') {
#         MaterializedTupleRef_V3993442750_0_1 _ret;
#
#
#
#                {
#                std::string _temp;
#                std::getline(ss, _temp, delim);
#                // beware; truncate= true, so unckecked truncation for stringlen >= MAX_STR_LEN!
#                _ret.f0 = to_array<MAX_STR_LEN, std::string, true>(_temp);
#                }
#
#
#
#                {
#                // use operator>> to parse into proper numeric type
#                ss >> _ret.f1;
#                //throw away the next delimiter
#                std::string _temp;
#                std::getline(ss, _temp, delim);
#                }
#
#
#
#         return _ret;
#     }
#
#     void toOStream(std::ostream& os) const {
#         os.write((char*)this, this->fieldsSize());
#     }
#
#     void toOStreamAscii(std::ostream& os) const {
#         os
#
#
#         << f0 << " "
#
#         << f1 <<
#
#         std::endl;
#     }
#
#     //template <typename Tuple, typename T>
#     //MaterializedTupleRef_V3993442750_0_1 (const Tuple& v0, const T& from) {
#     //    constexpr size_t v0_size = std::tuple_size<Tuple>::value;
#     //    constexpr int from_size = T::numFields();
#     //    static_assert(MaterializedTupleRef_V3993442750_0_1::numFields() == (v0_size + from_size), "constructor only works on same number of total fields");
#     //    TupleUtils::assign<0, decltype(_scheme)>(_fields, v0);
#     //    std::memcpy(((char*)&_fields)+v0_size*sizeof(int64_t), &(from._fields), from_size*sizeof(int64_t));
#     //}
#
#     //template <typename Tuple>
#     //MaterializedTupleRef_V3993442750_0_1 (const Tuple& v0) {
#     //    static_assert(MaterializedTupleRef_V3993442750_0_1::numFields() == (std::tuple_size<Tuple>::value), "constructor only works on same number of total fields");
#     //    TupleUtils::assign<0, decltype(_scheme)>(_fields, v0);
#     //}
#
#     std::ostream& dump(std::ostream& o) const {
#       o << "Materialized(";
#
#
#         o << f0 << ",";
#
#         o << f1 << ",";
#
#
#       o << ")";
#       return o;
#     }
#
#     public:
#     static MaterializedTupleRef_V3993442750_0_1 fromRelationInfo(relationInfo * rel, int row) {
#         // DOESN'T WORK WITH SCHEMAS WITH STRINGS
#       MaterializedTupleRef_V3993442750_0_1 _t;
#
#          _t.f0 = *(std::array<char, MAX_STR_LEN>*)(&(rel->relation[row*rel->fields+0]));
#
#          _t.f1 = *(double*)(&(rel->relation[row*rel->fields+1]));
#
#       return _t;
#     }
#   } ;
#
#   std::ostream& operator<< (std::ostream& o, const MaterializedTupleRef_V3993442750_0_1& t) {
#     return t.dump(o);
#   }
#
#           // can be just the necessary schema
#   class MaterializedTupleRef_V4636848921_0_1 {
#     // Invariant: data stored in _fields is always in the representation
#     // specified by _scheme.
#
#     public:
#
#         double f0;
#
#         std::array<char, MAX_STR_LEN> f1;
#
#
#     static constexpr int numFields() {
#       return 2;
#     }
#
#     // size of all fields in struct removing only end padding
#     static size_t fieldsSize() {
#         const MaterializedTupleRef_V4636848921_0_1 _t;
#         return
#
#
#             ((char*)&_t.f1) + sizeof(_t.f1) - ((char*)&_t);
#
#     }
#
#     // debugging function to get storage sizes
#     static void print_representation() {
#         const MaterializedTupleRef_V4636848921_0_1 _t;
#
#
#
#         std::cout << (((char*)&_t.f1) - ((char*)&_t.f0)) << ",";
#
#         std::cout << (_t.fieldsSize() - (((char*)&_t.f0) - ((char*)&_t)));
#         std::cout << std::endl;
#
#
#
#     }
#
#     MaterializedTupleRef_V4636848921_0_1 () {
#       // no-op
#     }
#
#     //template <typename OT>
#     //MaterializedTupleRef_V4636848921_0_1 (const OT& other) {
#     //  std::memcpy(this, &other, sizeof(MaterializedTupleRef_V4636848921_0_1));
#     //}
#
#     MaterializedTupleRef_V4636848921_0_1 (
#                                const double& a0
#                                ,
#
#                                const std::array<char, MAX_STR_LEN>& a1
#
#
#                        ) {
#
#             f0 = a0;
#
#             f1 = a1;
#
#     }
#
#
#
#
#
#
#     MaterializedTupleRef_V4636848921_0_1(const std::tuple<
#
#         double
#         ,
#
#         std::array<char, MAX_STR_LEN>
#
#
#             >& o) {
#
#             f0 = std::get<0>(o);
#
#             f1 = std::get<1>(o);
#
#      }
#
#      std::tuple<
#
#         double
#         ,
#
#         std::array<char, MAX_STR_LEN>
#
#
#      > to_tuple() {
#
#         std::tuple<
#
#         double
#         ,
#
#         std::array<char, MAX_STR_LEN>
#
#
#         > r;
#
#             std::get<0>(r) = f0;
#
#             std::get<1>(r) = f1;
#
#         return r;
#      }
#
#     // shamelessly terrible disambiguation: one solution is named factory methods
#     //MaterializedTupleRef_V4636848921_0_1 (std::vector<int64_t> vals, bool ignore1, bool ignore2) {
#     //
#     //        f0 = vals[0];
#     //
#     //        f1 = vals[1];
#     //
#     //}
#
#     // use the tuple schema to interpret the input stream
#     static MaterializedTupleRef_V4636848921_0_1 fromIStream(std::istream& ss, char delim=' ') {
#         MaterializedTupleRef_V4636848921_0_1 _ret;
#
#
#
#                {
#                // use operator>> to parse into proper numeric type
#                ss >> _ret.f0;
#                //throw away the next delimiter
#                std::string _temp;
#                std::getline(ss, _temp, delim);
#                }
#
#
#
#                {
#                std::string _temp;
#                std::getline(ss, _temp, delim);
#                // beware; truncate= true, so unckecked truncation for stringlen >= MAX_STR_LEN!
#                _ret.f1 = to_array<MAX_STR_LEN, std::string, true>(_temp);
#                }
#
#
#
#         return _ret;
#     }
#
#     void toOStream(std::ostream& os) const {
#         os.write((char*)this, this->fieldsSize());
#     }
#
#     void toOStreamAscii(std::ostream& os) const {
#         os
#
#
#         << f0 << " "
#
#         << f1 <<
#
#         std::endl;
#     }
#
#     //template <typename Tuple, typename T>
#     //MaterializedTupleRef_V4636848921_0_1 (const Tuple& v0, const T& from) {
#     //    constexpr size_t v0_size = std::tuple_size<Tuple>::value;
#     //    constexpr int from_size = T::numFields();
#     //    static_assert(MaterializedTupleRef_V4636848921_0_1::numFields() == (v0_size + from_size), "constructor only works on same number of total fields");
#     //    TupleUtils::assign<0, decltype(_scheme)>(_fields, v0);
#     //    std::memcpy(((char*)&_fields)+v0_size*sizeof(int64_t), &(from._fields), from_size*sizeof(int64_t));
#     //}
#
#     //template <typename Tuple>
#     //MaterializedTupleRef_V4636848921_0_1 (const Tuple& v0) {
#     //    static_assert(MaterializedTupleRef_V4636848921_0_1::numFields() == (std::tuple_size<Tuple>::value), "constructor only works on same number of total fields");
#     //    TupleUtils::assign<0, decltype(_scheme)>(_fields, v0);
#     //}
#
#     std::ostream& dump(std::ostream& o) const {
#       o << "Materialized(";
#
#
#         o << f0 << ",";
#
#         o << f1 << ",";
#
#
#       o << ")";
#       return o;
#     }
#
#     public:
#     static MaterializedTupleRef_V4636848921_0_1 fromRelationInfo(relationInfo * rel, int row) {
#         // DOESN'T WORK WITH SCHEMAS WITH STRINGS
#       MaterializedTupleRef_V4636848921_0_1 _t;
#
#          _t.f0 = *(double*)(&(rel->relation[row*rel->fields+0]));
#
#          _t.f1 = *(std::array<char, MAX_STR_LEN>*)(&(rel->relation[row*rel->fields+1]));
#
#       return _t;
#     }
#   } ;
#
#   std::ostream& operator<< (std::ostream& o, const MaterializedTupleRef_V4636848921_0_1& t) {
#     return t.dump(o);
#   }
#
#           // can be just the necessary schema
#   class MaterializedTupleRef_V9416092274_0 {
#     // Invariant: data stored in _fields is always in the representation
#     // specified by _scheme.
#
#     public:
#
#         std::array<char, MAX_STR_LEN> f0;
#
#
#     static constexpr int numFields() {
#       return 1;
#     }
#
#     // size of all fields in struct removing only end padding
#     static size_t fieldsSize() {
#         const MaterializedTupleRef_V9416092274_0 _t;
#         return
#
#
#             sizeof(_t.f0);
#
#     }
#
#     // debugging function to get storage sizes
#     static void print_representation() {
#         const MaterializedTupleRef_V9416092274_0 _t;
#
#
#         std::cout << _t.fieldsSize() << std::endl;
#
#
#
#     }
#
#     MaterializedTupleRef_V9416092274_0 () {
#       // no-op
#     }
#
#     //template <typename OT>
#     //MaterializedTupleRef_V9416092274_0 (const OT& other) {
#     //  std::memcpy(this, &other, sizeof(MaterializedTupleRef_V9416092274_0));
#     //}
#
#     MaterializedTupleRef_V9416092274_0 (
#                                const std::array<char, MAX_STR_LEN>& a0
#
#
#                        ) {
#
#             f0 = a0;
#
#     }
#
#
#
#
#
#
#     MaterializedTupleRef_V9416092274_0(const std::tuple<
#
#         std::array<char, MAX_STR_LEN>
#
#
#             >& o) {
#
#             f0 = std::get<0>(o);
#
#      }
#
#      std::tuple<
#
#         std::array<char, MAX_STR_LEN>
#
#
#      > to_tuple() {
#
#         std::tuple<
#
#         std::array<char, MAX_STR_LEN>
#
#
#         > r;
#
#             std::get<0>(r) = f0;
#
#         return r;
#      }
#
#     // shamelessly terrible disambiguation: one solution is named factory methods
#     //MaterializedTupleRef_V9416092274_0 (std::vector<int64_t> vals, bool ignore1, bool ignore2) {
#     //
#     //        f0 = vals[0];
#     //
#     //}
#
#     // use the tuple schema to interpret the input stream
#     static MaterializedTupleRef_V9416092274_0 fromIStream(std::istream& ss, char delim=' ') {
#         MaterializedTupleRef_V9416092274_0 _ret;
#
#
#
#                {
#                std::string _temp;
#                std::getline(ss, _temp, delim);
#                // beware; truncate= true, so unckecked truncation for stringlen >= MAX_STR_LEN!
#                _ret.f0 = to_array<MAX_STR_LEN, std::string, true>(_temp);
#                }
#
#
#
#         return _ret;
#     }
#
#     void toOStream(std::ostream& os) const {
#         os.write((char*)this, this->fieldsSize());
#     }
#
#     void toOStreamAscii(std::ostream& os) const {
#         os
#
#
#         << f0 <<
#
#         std::endl;
#     }
#
#     //template <typename Tuple, typename T>
#     //MaterializedTupleRef_V9416092274_0 (const Tuple& v0, const T& from) {
#     //    constexpr size_t v0_size = std::tuple_size<Tuple>::value;
#     //    constexpr int from_size = T::numFields();
#     //    static_assert(MaterializedTupleRef_V9416092274_0::numFields() == (v0_size + from_size), "constructor only works on same number of total fields");
#     //    TupleUtils::assign<0, decltype(_scheme)>(_fields, v0);
#     //    std::memcpy(((char*)&_fields)+v0_size*sizeof(int64_t), &(from._fields), from_size*sizeof(int64_t));
#     //}
#
#     //template <typename Tuple>
#     //MaterializedTupleRef_V9416092274_0 (const Tuple& v0) {
#     //    static_assert(MaterializedTupleRef_V9416092274_0::numFields() == (std::tuple_size<Tuple>::value), "constructor only works on same number of total fields");
#     //    TupleUtils::assign<0, decltype(_scheme)>(_fields, v0);
#     //}
#
#     std::ostream& dump(std::ostream& o) const {
#       o << "Materialized(";
#
#
#         o << f0 << ",";
#
#
#       o << ")";
#       return o;
#     }
#
#     public:
#     static MaterializedTupleRef_V9416092274_0 fromRelationInfo(relationInfo * rel, int row) {
#         // DOESN'T WORK WITH SCHEMAS WITH STRINGS
#       MaterializedTupleRef_V9416092274_0 _t;
#
#          _t.f0 = *(std::array<char, MAX_STR_LEN>*)(&(rel->relation[row*rel->fields+0]));
#
#       return _t;
#     }
#   } ;
#
#   std::ostream& operator<< (std::ostream& o, const MaterializedTupleRef_V9416092274_0& t) {
#     return t.dump(o);
#   }
#
#           // can be just the necessary schema
#   class MaterializedTupleRef_V7224555082_0_1_2 {
#     // Invariant: data stored in _fields is always in the representation
#     // specified by _scheme.
#
#     public:
#
#         std::array<char, MAX_STR_LEN> f0;
#
#         std::array<char, MAX_STR_LEN> f1;
#
#         std::array<char, MAX_STR_LEN> f2;
#
#
#     static constexpr int numFields() {
#       return 3;
#     }
#
#     // size of all fields in struct removing only end padding
#     static size_t fieldsSize() {
#         const MaterializedTupleRef_V7224555082_0_1_2 _t;
#         return
#
#
#             ((char*)&_t.f2) + sizeof(_t.f2) - ((char*)&_t);
#
#     }
#
#     // debugging function to get storage sizes
#     static void print_representation() {
#         const MaterializedTupleRef_V7224555082_0_1_2 _t;
#
#
#
#         std::cout << (((char*)&_t.f1) - ((char*)&_t.f0)) << ",";
#
#         std::cout << (((char*)&_t.f2) - ((char*)&_t.f1)) << ",";
#
#         std::cout << (_t.fieldsSize() - (((char*)&_t.f1) - ((char*)&_t)));
#         std::cout << std::endl;
#
#
#
#     }
#
#     MaterializedTupleRef_V7224555082_0_1_2 () {
#       // no-op
#     }
#
#     //template <typename OT>
#     //MaterializedTupleRef_V7224555082_0_1_2 (const OT& other) {
#     //  std::memcpy(this, &other, sizeof(MaterializedTupleRef_V7224555082_0_1_2));
#     //}
#
#     MaterializedTupleRef_V7224555082_0_1_2 (
#                                const std::array<char, MAX_STR_LEN>& a0
#                                ,
#
#                                const std::array<char, MAX_STR_LEN>& a1
#                                ,
#
#                                const std::array<char, MAX_STR_LEN>& a2
#
#
#                        ) {
#
#             f0 = a0;
#
#             f1 = a1;
#
#             f2 = a2;
#
#     }
#
#
#
#
#
#
#     MaterializedTupleRef_V7224555082_0_1_2(const std::tuple<
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         std::array<char, MAX_STR_LEN>
#
#
#             >& o) {
#
#             f0 = std::get<0>(o);
#
#             f1 = std::get<1>(o);
#
#             f2 = std::get<2>(o);
#
#      }
#
#      std::tuple<
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         std::array<char, MAX_STR_LEN>
#
#
#      > to_tuple() {
#
#         std::tuple<
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         std::array<char, MAX_STR_LEN>
#
#
#         > r;
#
#             std::get<0>(r) = f0;
#
#             std::get<1>(r) = f1;
#
#             std::get<2>(r) = f2;
#
#         return r;
#      }
#
#     // shamelessly terrible disambiguation: one solution is named factory methods
#     //MaterializedTupleRef_V7224555082_0_1_2 (std::vector<int64_t> vals, bool ignore1, bool ignore2) {
#     //
#     //        f0 = vals[0];
#     //
#     //        f1 = vals[1];
#     //
#     //        f2 = vals[2];
#     //
#     //}
#
#     // use the tuple schema to interpret the input stream
#     static MaterializedTupleRef_V7224555082_0_1_2 fromIStream(std::istream& ss, char delim=' ') {
#         MaterializedTupleRef_V7224555082_0_1_2 _ret;
#
#
#
#                {
#                std::string _temp;
#                std::getline(ss, _temp, delim);
#                // beware; truncate= true, so unckecked truncation for stringlen >= MAX_STR_LEN!
#                _ret.f0 = to_array<MAX_STR_LEN, std::string, true>(_temp);
#                }
#
#
#
#                {
#                std::string _temp;
#                std::getline(ss, _temp, delim);
#                // beware; truncate= true, so unckecked truncation for stringlen >= MAX_STR_LEN!
#                _ret.f1 = to_array<MAX_STR_LEN, std::string, true>(_temp);
#                }
#
#
#
#                {
#                std::string _temp;
#                std::getline(ss, _temp, delim);
#                // beware; truncate= true, so unckecked truncation for stringlen >= MAX_STR_LEN!
#                _ret.f2 = to_array<MAX_STR_LEN, std::string, true>(_temp);
#                }
#
#
#
#         return _ret;
#     }
#
#     void toOStream(std::ostream& os) const {
#         os.write((char*)this, this->fieldsSize());
#     }
#
#     void toOStreamAscii(std::ostream& os) const {
#         os
#
#
#         << f0 << " "
#
#         << f1 << " "
#
#         << f2 <<
#
#         std::endl;
#     }
#
#     //template <typename Tuple, typename T>
#     //MaterializedTupleRef_V7224555082_0_1_2 (const Tuple& v0, const T& from) {
#     //    constexpr size_t v0_size = std::tuple_size<Tuple>::value;
#     //    constexpr int from_size = T::numFields();
#     //    static_assert(MaterializedTupleRef_V7224555082_0_1_2::numFields() == (v0_size + from_size), "constructor only works on same number of total fields");
#     //    TupleUtils::assign<0, decltype(_scheme)>(_fields, v0);
#     //    std::memcpy(((char*)&_fields)+v0_size*sizeof(int64_t), &(from._fields), from_size*sizeof(int64_t));
#     //}
#
#     //template <typename Tuple>
#     //MaterializedTupleRef_V7224555082_0_1_2 (const Tuple& v0) {
#     //    static_assert(MaterializedTupleRef_V7224555082_0_1_2::numFields() == (std::tuple_size<Tuple>::value), "constructor only works on same number of total fields");
#     //    TupleUtils::assign<0, decltype(_scheme)>(_fields, v0);
#     //}
#
#     std::ostream& dump(std::ostream& o) const {
#       o << "Materialized(";
#
#
#         o << f0 << ",";
#
#         o << f1 << ",";
#
#         o << f2 << ",";
#
#
#       o << ")";
#       return o;
#     }
#
#     public:
#     static MaterializedTupleRef_V7224555082_0_1_2 fromRelationInfo(relationInfo * rel, int row) {
#         // DOESN'T WORK WITH SCHEMAS WITH STRINGS
#       MaterializedTupleRef_V7224555082_0_1_2 _t;
#
#          _t.f0 = *(std::array<char, MAX_STR_LEN>*)(&(rel->relation[row*rel->fields+0]));
#
#          _t.f1 = *(std::array<char, MAX_STR_LEN>*)(&(rel->relation[row*rel->fields+1]));
#
#          _t.f2 = *(std::array<char, MAX_STR_LEN>*)(&(rel->relation[row*rel->fields+2]));
#
#       return _t;
#     }
#   } ;
#
#   std::ostream& operator<< (std::ostream& o, const MaterializedTupleRef_V7224555082_0_1_2& t) {
#     return t.dump(o);
#   }
#
# std::vector<MaterializedTupleRef_V7224555082_0_1_2> V7224555082;
# std::unordered_map<std::array<char, MAX_STR_LEN>, std::vector<MaterializedTupleRef_V9416092274_0> > hash_001;
#           // can be just the necessary schema
#   class MaterializedTupleRef_V6048429802_0_1_2 {
#     // Invariant: data stored in _fields is always in the representation
#     // specified by _scheme.
#
#     public:
#
#         std::array<char, MAX_STR_LEN> f0;
#
#         double f1;
#
#         std::array<char, MAX_STR_LEN> f2;
#
#
#     static constexpr int numFields() {
#       return 3;
#     }
#
#     // size of all fields in struct removing only end padding
#     static size_t fieldsSize() {
#         const MaterializedTupleRef_V6048429802_0_1_2 _t;
#         return
#
#
#             ((char*)&_t.f2) + sizeof(_t.f2) - ((char*)&_t);
#
#     }
#
#     // debugging function to get storage sizes
#     static void print_representation() {
#         const MaterializedTupleRef_V6048429802_0_1_2 _t;
#
#
#
#         std::cout << (((char*)&_t.f1) - ((char*)&_t.f0)) << ",";
#
#         std::cout << (((char*)&_t.f2) - ((char*)&_t.f1)) << ",";
#
#         std::cout << (_t.fieldsSize() - (((char*)&_t.f1) - ((char*)&_t)));
#         std::cout << std::endl;
#
#
#
#     }
#
#     MaterializedTupleRef_V6048429802_0_1_2 () {
#       // no-op
#     }
#
#     //template <typename OT>
#     //MaterializedTupleRef_V6048429802_0_1_2 (const OT& other) {
#     //  std::memcpy(this, &other, sizeof(MaterializedTupleRef_V6048429802_0_1_2));
#     //}
#
#     MaterializedTupleRef_V6048429802_0_1_2 (
#                                const std::array<char, MAX_STR_LEN>& a0
#                                ,
#
#                                const double& a1
#                                ,
#
#                                const std::array<char, MAX_STR_LEN>& a2
#
#
#                        ) {
#
#             f0 = a0;
#
#             f1 = a1;
#
#             f2 = a2;
#
#     }
#
#
#
#
#
#
#     MaterializedTupleRef_V6048429802_0_1_2(const std::tuple<
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         double
#         ,
#
#         std::array<char, MAX_STR_LEN>
#
#
#             >& o) {
#
#             f0 = std::get<0>(o);
#
#             f1 = std::get<1>(o);
#
#             f2 = std::get<2>(o);
#
#      }
#
#      std::tuple<
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         double
#         ,
#
#         std::array<char, MAX_STR_LEN>
#
#
#      > to_tuple() {
#
#         std::tuple<
#
#         std::array<char, MAX_STR_LEN>
#         ,
#
#         double
#         ,
#
#         std::array<char, MAX_STR_LEN>
#
#
#         > r;
#
#             std::get<0>(r) = f0;
#
#             std::get<1>(r) = f1;
#
#             std::get<2>(r) = f2;
#
#         return r;
#      }
#
#     // shamelessly terrible disambiguation: one solution is named factory methods
#     //MaterializedTupleRef_V6048429802_0_1_2 (std::vector<int64_t> vals, bool ignore1, bool ignore2) {
#     //
#     //        f0 = vals[0];
#     //
#     //        f1 = vals[1];
#     //
#     //        f2 = vals[2];
#     //
#     //}
#
#     // use the tuple schema to interpret the input stream
#     static MaterializedTupleRef_V6048429802_0_1_2 fromIStream(std::istream& ss, char delim=' ') {
#         MaterializedTupleRef_V6048429802_0_1_2 _ret;
#
#
#
#                {
#                std::string _temp;
#                std::getline(ss, _temp, delim);
#                // beware; truncate= true, so unckecked truncation for stringlen >= MAX_STR_LEN!
#                _ret.f0 = to_array<MAX_STR_LEN, std::string, true>(_temp);
#                }
#
#
#
#                {
#                // use operator>> to parse into proper numeric type
#                ss >> _ret.f1;
#                //throw away the next delimiter
#                std::string _temp;
#                std::getline(ss, _temp, delim);
#                }
#
#
#
#                {
#                std::string _temp;
#                std::getline(ss, _temp, delim);
#                // beware; truncate= true, so unckecked truncation for stringlen >= MAX_STR_LEN!
#                _ret.f2 = to_array<MAX_STR_LEN, std::string, true>(_temp);
#                }
#
#
#
#         return _ret;
#     }
#
#     void toOStream(std::ostream& os) const {
#         os.write((char*)this, this->fieldsSize());
#     }
#
#     void toOStreamAscii(std::ostream& os) const {
#         os
#
#
#         << f0 << " "
#
#         << f1 << " "
#
#         << f2 <<
#
#         std::endl;
#     }
#
#     //template <typename Tuple, typename T>
#     //MaterializedTupleRef_V6048429802_0_1_2 (const Tuple& v0, const T& from) {
#     //    constexpr size_t v0_size = std::tuple_size<Tuple>::value;
#     //    constexpr int from_size = T::numFields();
#     //    static_assert(MaterializedTupleRef_V6048429802_0_1_2::numFields() == (v0_size + from_size), "constructor only works on same number of total fields");
#     //    TupleUtils::assign<0, decltype(_scheme)>(_fields, v0);
#     //    std::memcpy(((char*)&_fields)+v0_size*sizeof(int64_t), &(from._fields), from_size*sizeof(int64_t));
#     //}
#
# ...
#
#
#       o << ")";
#       return o;
#     }
#
#     public:
#     static MaterializedTupleRef_V7737922010_0_1_2_3_4_5 fromRelationInfo(relationInfo * rel, int row) {
#         // DOESN'T WORK WITH SCHEMAS WITH STRINGS
#       MaterializedTupleRef_V7737922010_0_1_2_3_4_5 _t;
#
#          _t.f0 = *(std::array<char, MAX_STR_LEN>*)(&(rel->relation[row*rel->fields+0]));
#
#          _t.f1 = *(std::array<char, MAX_STR_LEN>*)(&(rel->relation[row*rel->fields+1]));
#
#          _t.f2 = *(int64_t*)(&(rel->relation[row*rel->fields+2]));
#
#          _t.f3 = *(int64_t*)(&(rel->relation[row*rel->fields+3]));
#
#          _t.f4 = *(std::array<char, MAX_STR_LEN>*)(&(rel->relation[row*rel->fields+4]));
#
#          _t.f5 = *(int64_t*)(&(rel->relation[row*rel->fields+5]));
#
#       return _t;
#     }
#   } ;
#
#   std::ostream& operator<< (std::ostream& o, const MaterializedTupleRef_V7737922010_0_1_2_3_4_5& t) {
#     return t.dump(o);
#   }
#
# static MaterializedTupleRef_V7737922010_0_1_2_3_4_5 create_V4379456896(const MaterializedTupleRef_V3235663131_0_1_2_3& t1, const MaterializedTupleRef_V1141216908_0_1& t2) {
#     MaterializedTupleRef_V7737922010_0_1_2_3_4_5 t;
#
#         t.f0 = t1.f0;
#
#         t.f1 = t1.f1;
#
#         t.f2 = t1.f2;
#
#         t.f3 = t1.f3;
#
#
#
#         t.f4 = t2.f0;
#
#         t.f5 = t2.f1;
#
#
#     return t;
# }
# std::vector<MaterializedTupleRef_V8596059147_0_1_2> result;
#
#
# StringIndex string_index;
# void init( ) {
# }
#
#
# void query(struct relationInfo *resultInfo)
# {
#   printf("\nstarting Query stdout\n");fflush(stdout);
#
#   double start = timer();
#
#   uint64 resultcount = 0;
#   struct relationInfo __result___val;
#   struct relationInfo *__result__ = &__result___val;
#
#
#   // -----------------------------------------------------------
#   // Fill in query here
#   // -----------------------------------------------------------
#
#
#
#
# auto start_V4597468686 = walltime();
# auto start_0 = walltime();
#
# std::cout  << "timestamp 0 start " << std::setprecision(15) << start_0 << std::endl;
#
#
# auto V7224555082 = tuplesFromAscii<MaterializedTupleRef_V7224555082_0_1_2>("/home/dhutchis/gits/raco/examples/fed_accumulo_spark_c/dnssample_parsed.txt");
#
# auto end_0 = walltime();
# auto runtime_0 = end_0 - start_0;
#
# std::cout  << "pipeline 0: " << runtime_0 << " s" << std::endl;
#
#
#
# std::cout  << "timestamp 0 end " << std::setprecision(15) << end_0 << std::endl;
#
#
# auto start_3 = walltime();
#
# std::cout  << "timestamp 3 start " << std::setprecision(15) << start_3 << std::endl;
#
#
# auto V7340547019 = tuplesFromAscii<MaterializedTupleRef_V7340547019_0_1_2>("V176100730");
#
# auto end_3 = walltime();
# auto runtime_3 = end_3 - start_3;
#
# std::cout  << "pipeline 3: " << runtime_3 << " s" << std::endl;
#
#
#
# std::cout  << "timestamp 3 end " << std::setprecision(15) << end_3 << std::endl;
#
#
# auto start_6 = walltime();
#
# std::cout  << "timestamp 6 start " << std::setprecision(15) << start_6 << std::endl;
#
#
# auto V2608232279 = tuplesFromAscii<MaterializedTupleRef_V2608232279_0_1_2>("V9297803253");
#
# auto end_6 = walltime();
# auto runtime_6 = end_6 - start_6;
#
# std::cout  << "pipeline 6: " << runtime_6 << " s" << std::endl;
#
#
#
# std::cout  << "timestamp 6 end " << std::setprecision(15) << end_6 << std::endl;
#
#
# auto start_9 = walltime();
#
# std::cout  << "timestamp 9 start " << std::setprecision(15) << start_9 << std::endl;
#
#
# auto V5348579493 = tuplesFromAscii<MaterializedTupleRef_V5348579493_0_1_2>("V1221451602");
#
# auto end_9 = walltime();
# auto runtime_9 = end_9 - start_9;
#
# std::cout  << "pipeline 9: " << runtime_9 << " s" << std::endl;
#
#
#
# std::cout  << "timestamp 9 end " << std::setprecision(15) << end_9 << std::endl;
#
#
# auto start_11 = walltime();
#
# std::cout  << "timestamp 11 start " << std::setprecision(15) << start_11 << std::endl;
#
#
# auto V849453468 = tuplesFromAscii<MaterializedTupleRef_V849453468_0_1_2>("V1317968015");
#
# auto end_11 = walltime();
# auto runtime_11 = end_11 - start_11;
#
# std::cout  << "pipeline 11: " << runtime_11 << " s" << std::endl;
#
#
#
# std::cout  << "timestamp 11 end " << std::setprecision(15) << end_11 << std::endl;
#
#
# auto end_V4597468686 = walltime();
#
# auto runtime_V4597468686 = end_V4597468686 - start_V4597468686;
#
# std::cout << "pipeline group V4597468686: "
#           << runtime_V4597468686
#           << " s" << std::endl;
#
# auto start_V4852051492 = walltime();
# // Compiled subplan for CStore(public:adhoc:nameJaccard)[CApply(src_name=$0,dst_name=$1,jaccard_coeff=($2 / (($3 + $4) - $2)))[CApply(u=$0,v=$1,gamma=$2,od=$3,od1=$5)[CHashJoin(($1 = $4))[CApply(u=$0,v=$1,gamma=$2,od=$4)[CHashJoin(($0 = $3))[CApply(u=$0,v=$1,gamma=$2)[CGroupBy($0,$1; COUNT($2))[CApply(row=$0,row1=$1,value1=$2)[CApply(row=$0,row1=$2,value=$4)[CHashJoin(($1 = $3))[CApply(row=$0,col=$1)[CApply(dns=$2,dns1=$4)[CHashJoin(($0 = $3))[CApply(dst_ip=$1,value=$2,dns=$4)[CHashJoin(($0 = $3))[CMemoryScan[CFileScan(public:adhoc:V1317968015)],CApply(ip=$1,dns=$2)[CMemoryScan[CFileScan(public:adhoc:/home/dhutchis/gits/raco/examples/fed_accumulo_spark_c/dnssample_parsed.txt)]]]],CApply(ip=$1,dns=$2)[CMemoryScan[CFileScan(public:adhoc:/home/dhutchis/gits/raco/examples/fed_accumulo_spark_c/dnssample_parsed.txt)]]]]],CApply(row=$1,col=$2,value=$0)[CApply(value=$1,dns=$2,dns1=$4)[CHashJoin(($0 = $3))[CApply(dst_ip=$1,value=$2,dns=$4)[CHashJoin(($0 = $3))[CMemoryScan[CFileScan(public:adhoc:V1221451602)],CApply(ip=$1,dns=$2)[CMemoryScan[CFileScan(public:adhoc:/home/dhutchis/gits/raco/examples/fed_accumulo_spark_c/dnssample_parsed.txt)]]]],CApply(ip=$1,dns=$2)[CMemoryScan[CFileScan(public:adhoc:/home/dhutchis/gits/raco/examples/fed_accumulo_spark_c/dnssample_parsed.txt)]]]]]]]]]],CApply(row=$0,od=$1)[CGroupBy($0; COUNT($1))[CApply(row=$1,value=$0)[CApply(value=$1,dns=$2)[CHashJoin(($0 = $3))[CApply(dst_ip=$1,value=$2,dns=$4)[CHashJoin(($0 = $3))[CMemoryScan[CFileScan(public:adhoc:V9297803253)],CApply(ip=$1,dns=$2)[CMemoryScan[CFileScan(public:adhoc:/home/dhutchis/gits/raco/examples/fed_accumulo_spark_c/dnssample_parsed.txt)]]]],CApply(ip=$1)[CMemoryScan[CFileScan(public:adhoc:/home/dhutchis/gits/raco/examples/fed_accumulo_spark_c/dnssample_parsed.txt)]]]]]]]]],CApply(row=$0,od=$1)[CGroupBy($0; COUNT($1))[CApply(row=$1,value=$0)[CApply(value=$1,dns=$2)[CHashJoin(($0 = $3))[CApply(dst_ip=$1,value=$2,dns=$4)[CHashJoin(($0 = $3))[CMemoryScan[CFileScan(public:adhoc:V176100730)],CApply(ip=$1,dns=$2)[CMemoryScan[CFileScan(public:adhoc:/home/dhutchis/gits/raco/examples/fed_accumulo_spark_c/dnssample_parsed.txt)]]]],CApply(ip=$1)[CMemoryScan[CFileScan(public:adhoc:/home/dhutchis/gits/raco/examples/fed_accumulo_spark_c/dnssample_parsed.txt)]]]]]]]]]]]
#
# auto start_1 = walltime();
#
# std::cout  << "timestamp 1 start " << std::setprecision(15) << start_1 << std::endl;
#
#
# for (auto t_006 : V7224555082) {
#     // CApply(ip=$1)
# MaterializedTupleRef_V9416092274_0 t_005;t_005.f0 = t_006.f1;
# insert(hash_001, t_005.f0, t_005);
# } // end scan over V7224555082
# auto end_1 = walltime();
# auto runtime_1 = end_1 - start_1;
#
# std::cout  << "pipeline 1: " << runtime_1 << " s" << std::endl;
#
#
#
# std::cout  << "timestamp 1 end " << std::setprecision(15) << end_1 << std::endl;
#
#
# auto start_2 = walltime();
#
# std::cout  << "timestamp 2 start " << std::setprecision(15) << start_2 << std::endl;
#
#
# for (auto t_006 : V7224555082) {
#     // CApply(ip=$1,dns=$2)
# MaterializedTupleRef_V7253692168_0_1 t_008;t_008.f0 = t_006.f1;
# t_008.f1 = t_006.f2;
# insert(hash_002, t_008.f0, t_008);
# } // end scan over V7224555082
# auto end_2 = walltime();
# auto runtime_2 = end_2 - start_2;
#
# std::cout  << "pipeline 2: " << runtime_2 << " s" << std::endl;
#
#
#
# std::cout  << "timestamp 2 end " << std::setprecision(15) << end_2 << std::endl;
#
#
# auto start_4 = walltime();
#
# std::cout  << "timestamp 4 start " << std::setprecision(15) << start_4 << std::endl;
#
#
# for (auto t_009 : V7340547019) {
#     for (auto V4962812459 : lookup(hash_002, t_009.f0)) {
#     auto t_010 = create_V2450208247(t_009, V4962812459);
#     // CApply(dst_ip=$1,value=$2,dns=$4)
# MaterializedTupleRef_V6048429802_0_1_2 t_007;t_007.f0 = t_010.f1;
# t_007.f1 = t_010.f2;
# t_007.f2 = t_010.f4;
# for (auto V1116426954 : lookup(hash_001, t_007.f0)) {
#     auto t_011 = create_V5300031952(t_007, V1116426954);
#     // CApply(value=$1,dns=$2)
# MaterializedTupleRef_V4636848921_0_1 t_004;t_004.f0 = t_011.f1;
# t_004.f1 = t_011.f2;
# // CApply(row=$1,value=$0)
# MaterializedTupleRef_V3993442750_0_1 t_003;t_003.f0 = t_004.f1;
# t_003.f1 = t_004.f0;
# COUNT_insert(group_hash_000, t_003.f0, t_003.f1);
# }
# }
# } // end scan over V7340547019
# auto end_4 = walltime();
# auto runtime_4 = end_4 - start_4;
#
# std::cout  << "pipeline 4: " << runtime_4 << " s" << std::endl;
#
#
#
# std::cout  << "timestamp 4 end " << std::setprecision(15) << end_4 << std::endl;
#
#
# auto start_5 = walltime();
#
# std::cout  << "timestamp 5 start " << std::setprecision(15) << start_5 << std::endl;
#
#
# for (auto it=group_hash_000.begin(); it!=group_hash_000.end(); it++) {
#     MaterializedTupleRef_V9397345005_0_1 t_012(it->first, it->second);
#     // CApply(row=$0,od=$1)
# MaterializedTupleRef_V1141216908_0_1 t_002;t_002.f0 = t_012.f0;
# t_002.f1 = t_012.f1;
# insert(hash_000, t_002.f0, t_002);
# }
# auto end_5 = walltime();
# auto runtime_5 = end_5 - start_5;
#
# std::cout  << "pipeline 5: " << runtime_5 << " s" << std::endl;
#
#
#
# std::cout  << "timestamp 5 end " << std::setprecision(15) << end_5 << std::endl;
#
#
# auto start_7 = walltime();
#
# std::cout  << "timestamp 7 start " << std::setprecision(15) << start_7 << std::endl;
#
#
# for (auto t_018 : V2608232279) {
#     for (auto V3961999122 : lookup(hash_002, t_018.f0)) {
#     auto t_019 = create_V6707642365(t_018, V3961999122);
#     // CApply(dst_ip=$1,value=$2,dns=$4)
# MaterializedTupleRef_V2995726684_0_1_2 t_017;t_017.f0 = t_019.f1;
# t_017.f1 = t_019.f2;
# t_017.f2 = t_019.f4;
# for (auto V9633435759 : lookup(hash_001, t_017.f0)) {
#     auto t_020 = create_V7184896213(t_017, V9633435759);
#     // CApply(value=$1,dns=$2)
# MaterializedTupleRef_V4691038984_0_1 t_016;t_016.f0 = t_020.f1;
# t_016.f1 = t_020.f2;
# // CApply(row=$1,value=$0)
# MaterializedTupleRef_V6372235146_0_1 t_015;t_015.f0 = t_016.f1;
# t_015.f1 = t_016.f0;
# COUNT_insert(group_hash_001, t_015.f0, t_015.f1);
# }
# }
# } // end scan over V2608232279
# auto end_7 = walltime();
# auto runtime_7 = end_7 - start_7;
#
# std::cout  << "pipeline 7: " << runtime_7 << " s" << std::endl;
#
#
#
# std::cout  << "timestamp 7 end " << std::setprecision(15) << end_7 << std::endl;
#
#
# auto start_8 = walltime();
#
# std::cout  << "timestamp 8 start " << std::setprecision(15) << start_8 << std::endl;
#
#
# for (auto it=group_hash_001.begin(); it!=group_hash_001.end(); it++) {
#     MaterializedTupleRef_V7200405878_0_1 t_021(it->first, it->second);
#     // CApply(row=$0,od=$1)
# MaterializedTupleRef_V4459887985_0_1 t_014;t_014.f0 = t_021.f0;
# t_014.f1 = t_021.f1;
# insert(hash_003, t_014.f0, t_014);
# }
# auto end_8 = walltime();
# auto runtime_8 = end_8 - start_8;
#
# std::cout  << "pipeline 8: " << runtime_8 << " s" << std::endl;
#
#
#
# std::cout  << "timestamp 8 end " << std::setprecision(15) << end_8 << std::endl;
#
#
# auto start_10 = walltime();
#
# std::cout  << "timestamp 10 start " << std::setprecision(15) << start_10 << std::endl;
#
#
# for (auto t_028 : V5348579493) {
#     for (auto V251807843 : lookup(hash_002, t_028.f0)) {
#     auto t_029 = create_V7113399217(t_028, V251807843);
#     // CApply(dst_ip=$1,value=$2,dns=$4)
# MaterializedTupleRef_V8850499380_0_1_2 t_027;t_027.f0 = t_029.f1;
# t_027.f1 = t_029.f2;
# t_027.f2 = t_029.f4;
# for (auto V6737809604 : lookup(hash_002, t_027.f0)) {
#     auto t_030 = create_V3271549029(t_027, V6737809604);
#     // CApply(value=$1,dns=$2,dns1=$4)
# MaterializedTupleRef_V656631928_0_1_2 t_026;t_026.f0 = t_030.f1;
# t_026.f1 = t_030.f2;
# t_026.f2 = t_030.f4;
# // CApply(row=$1,col=$2,value=$0)
# MaterializedTupleRef_V6119530062_0_1_2 t_025;t_025.f0 = t_026.f1;
# t_025.f1 = t_026.f2;
# t_025.f2 = t_026.f0;
# insert(hash_004, t_025.f1, t_025);
# }
# }
# } // end scan over V5348579493
# auto end_10 = walltime();
# auto runtime_10 = end_10 - start_10;
#
# std::cout  << "pipeline 10: " << runtime_10 << " s" << std::endl;
#
#
#
# std::cout  << "timestamp 10 end " << std::setprecision(15) << end_10 << std::endl;
#
#
# auto start_12 = walltime();
#
# std::cout  << "timestamp 12 start " << std::setprecision(15) << start_12 << std::endl;
#
#
# for (auto t_034 : V849453468) {
#     for (auto V751005156 : lookup(hash_002, t_034.f0)) {
#     auto t_035 = create_V4990367696(t_034, V751005156);
#     // CApply(dst_ip=$1,value=$2,dns=$4)
# MaterializedTupleRef_V8374000886_0_1_2 t_033;t_033.f0 = t_035.f1;
# t_033.f1 = t_035.f2;
# t_033.f2 = t_035.f4;
# for (auto V5673753934 : lookup(hash_002, t_033.f0)) {
#     auto t_036 = create_V9386787614(t_033, V5673753934);
#     // CApply(dns=$2,dns1=$4)
# MaterializedTupleRef_V4220935663_0_1 t_032;t_032.f0 = t_036.f2;
# t_032.f1 = t_036.f4;
# // CApply(row=$0,col=$1)
# MaterializedTupleRef_V5204390349_0_1 t_031;t_031.f0 = t_032.f0;
# t_031.f1 = t_032.f1;
# for (auto V2675801533 : lookup(hash_004, t_031.f1)) {
#     auto t_037 = create_V7995632694(t_031, V2675801533);
#     // CApply(row=$0,row1=$2,value=$4)
# MaterializedTupleRef_V6197126043_0_1_2 t_024;t_024.f0 = t_037.f0;
# t_024.f1 = t_037.f2;
# t_024.f2 = t_037.f4;
# // CApply(row=$0,row1=$1,value1=$2)
# MaterializedTupleRef_V2830952755_0_1_2 t_023;t_023.f0 = t_024.f0;
# t_023.f1 = t_024.f1;
# t_023.f2 = t_024.f2;
# COUNT_insert(group_hash_002, t_023.f0, t_023.f1, t_023.f2);
# }
# }
# }
# } // end scan over V849453468
# auto end_12 = walltime();
# auto runtime_12 = end_12 - start_12;
#
# std::cout  << "pipeline 12: " << runtime_12 << " s" << std::endl;
#
#
#
# std::cout  << "timestamp 12 end " << std::setprecision(15) << end_12 << std::endl;
#
#
# auto start_13 = walltime();
#
# std::cout  << "timestamp 13 start " << std::setprecision(15) << start_13 << std::endl;
#
#
# for (auto it=group_hash_002.begin(); it!=group_hash_002.end(); it++) {
#     MaterializedTupleRef_V2957621458_0_1_2 t_038(it->first.first, it->first.second, it->second);
#     // CApply(u=$0,v=$1,gamma=$2)
# MaterializedTupleRef_V6843099088_0_1_2 t_022;t_022.f0 = t_038.f0;
# t_022.f1 = t_038.f1;
# t_022.f2 = t_038.f2;
# for (auto V1884786733 : lookup(hash_003, t_022.f0)) {
#     auto t_039 = create_V8198629421(t_022, V1884786733);
#     // CApply(u=$0,v=$1,gamma=$2,od=$4)
# MaterializedTupleRef_V3235663131_0_1_2_3 t_013;t_013.f0 = t_039.f0;
# t_013.f1 = t_039.f1;
# t_013.f2 = t_039.f2;
# t_013.f3 = t_039.f4;
# for (auto V5167353846 : lookup(hash_000, t_013.f1)) {
#     auto t_040 = create_V4379456896(t_013, V5167353846);
#     // CApply(u=$0,v=$1,gamma=$2,od=$3,od1=$5)
# MaterializedTupleRef_V2356188225_0_1_2_3_4 t_001;t_001.f0 = t_040.f0;
# t_001.f1 = t_040.f1;
# t_001.f2 = t_040.f2;
# t_001.f3 = t_040.f3;
# t_001.f4 = t_040.f5;
# // CApply(src_name=$0,dst_name=$1,jaccard_coeff=($2 / (($3 + $4) - $2)))
# MaterializedTupleRef_V8596059147_0_1_2 t_000;t_000.f0 = t_001.f0;
# t_000.f1 = t_001.f1;
# t_000.f2 = ( (t_001.f2) / (( (( (t_001.f3) + (t_001.f4) )) - (t_001.f2) )) );
# result.push_back(t_000);
# std::cout << t_000 << std::endl;
#
# }
# }
# }
# auto end_13 = walltime();
# auto runtime_13 = end_13 - start_13;
#
# std::cout  << "pipeline 13: " << runtime_13 << " s" << std::endl;
#
#
#
# std::cout  << "timestamp 13 end " << std::setprecision(15) << end_13 << std::endl;
#
#
# auto end_V4852051492 = walltime();
#
# auto runtime_V4852051492 = end_V4852051492 - start_V4852051492;
#
# std::cout << "pipeline group V4852051492: "
#           << runtime_V4852051492
#           << " s" << std::endl;
#
#
#
#
#   // return final result
#   resultInfo->tuples = __result__->tuples;
#   resultInfo->fields = __result__->fields;
#   resultInfo->relation = __result__->relation;
#
# }
#
#
#
# int main(int argc, char **argv) {
#
#   struct relationInfo resultInfo;
#
#   init();
#
#     printf("post-init stdout\n");fflush(stdout);
#
#   // Execute the query
#   query(&resultInfo);
#
#     printf("post-query stdout\n");fflush(stdout);
#
#     std::ofstream outputfile;
#     outputfile.open("matrix_output");
#     for (auto outTuple : result) {
#         outTuple.toOStreamAscii(outputfile);
#     }
#     outputfile.close();
# #ifdef ZAPPA
# //  printrelation(&resultInfo);
# #endif
# //  free(resultInfo.relation);
#
#     printf("exiting stdout\n");fflush(stdout);
#
# }

# %%
accumuloconn.setTableProperty('public_adhoc_netflow','table.custom.scheme','[("TotBytes","LONG_TYPE"),("StartTime","STRING_TYPE"),("SrcAddr","STRING_TYPE"),("DstAddr","STRING_TYPE"),("RATE","DOUBLE_TYPE"),("Dur","DOUBLE_TYPE"),("Dir","STRING_TYPE"),("Proto","STRING_TYPE"),("Sport","STRING_TYPE"),("Dport","STRING_TYPE"),("State","STRING_TYPE"),("sTos","LONG_TYPE"),("dTos","LONG_TYPE"),("TotPkts","LONG_TYPE"),("SrcBytes","LONG_TYPE"),("Label","STRING_TYPE")]')
accumuloconn.setTableProperty('public_adhoc_netflow','table.custom.howPartitioned','["TotBytes", "StartTime"]')
